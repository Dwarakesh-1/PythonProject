# %%
def homework_menu(user1):
    hw = ''' 
1 : BMI
2 : Calculate percentage
3 : Remainder, Larger, Smaller
4 : List Sequence with 0
5 : File Handling
6 : Dictonary
7 : Pandas Basics
8 : Health Club Data, Orng data
9 : Data Visualization Question 1, Data Visualization Question 2
10 : Class Address'''
    if user1 == '0':
        print("End of the program")
    else:
        while user1 != '0':
            try:
                user = int(user1)
                if user >= 1 and user <= 10:
                    if user == 1:
                        print(f"Homework {user}: BMI")
                        from Homework_1 import main
                        main()
                    elif user == 2:
                        print(f"Homework {user}: Calculate the percenatge of user answers")
                        from Homework_2 import main
                        main()
                    elif user == 3:
                        print(f"Homework {user}: Find the remainder, larger and smaller number")
                        from Homework_3 import main
                        main()
                    elif user == 4:
                        print(f"Homework {user}: List Sequence with 0")
                        from Homework_4 import main
                        main()
                    elif user == 5:
                        print(f"Homework {user}: Copy data from file one, two to third")
                        from Homework_5 import main
                        main()
                    elif user == 6:
                        print(f"Homework {user}: Dictonary for employee")
                        from Homework_6 import main
                        main()
                    elif user == 7:
                        print(f"Homework {user}: Pandas Basics")
                        from Homework_7 import main
                        main()
                    elif user == 8:
                        print(f"Homework {user}.1: Health Club Data")
                        from Homework_8_1 import main
                        main()
                        print()
                        print(f"Homework {user}.2: Orng data")
                        from Homework_8_2 import main
                        main()
                    elif user == 9:
                        print(f"Homework {user}.1: Data Visualization Question 1")
                        from Homework_9_1 import main
                        main()
                        print()
                        print(f"Homework {user}.2: Data Visualization Question 2")
                        from Homework_9_2 import main
                        main()
                    elif user == 10:
                        print(f"Homework {user}: Class Address")
                        from Homework_10 import main
                        main()
                else:
                    print(f"Homework {user} is not avaialable")
            except ValueError:
                print("Don't enter anything other than numbers")
            break


        print(hw)
        user1 = input("Enter the number of homework to perform (or 0 to end): ")
        homework_menu(user1)

# %%
hw = ''' 
1 : BMI
2 : Calculate percentage
3 : Remainder, Larger, Smaller
4 : List Sequence with 0
5 : File Handling
6 : Dictonary
7 : Pandas Basics
8 : Health Club Data, Orng data
9 : Data Visualization Question 1, Data Visualization Question 2
10 : Class Address'''

print(hw)
user1 = input("Enter the number of homework to perform (or 0 to end): ")
print()
homework_menu(user1)
# Out:
#
# 1 : BMI
# 2 : Calculate percentage
# 3 : Remainder, Larger, Smaller
# 4 : List Sequence with 0
# 5 : File Handling
# 6 : Dictonary
# 7 : Pandas Basics
# 8 : Health Club Data, Orng data
# 9 : Data Visualization Question 1, Data Visualization Question 2
# 10 : Class Address
# Enter the number of homework to perform (or 0 to end): 5
#
# Homework 5: Copy data from file one, two to third
# [3, 13, 15, 9, 18, 4, 7, 11, 6, 16, 0, 5]
# [2, 3, 4, 16, 0, 5, 19, 7, 0, 14, 32, 11, 8, 11, 9, 17]
# [3, 13, 15, 9, 18, 4, 7, 11, 6, 16, 0, 5]
# [2, 3, 4, 16, 0, 5, 19, 7, 0, 14, 32, 11, 8, 11, 9, 17]
#
# 1 : BMI
# 2 : Calculate percentage
# 3 : Remainder, Larger, Smaller
# 4 : List Sequence with 0
# 5 : File Handling
# 6 : Dictonary
# 7 : Pandas Basics
# 8 : Health Club Data, Orng data
# 9 : Data Visualization Question 1, Data Visualization Question 2
# 10 : Class Address
# Enter the number of homework to perform (or 0 to end): 5
# Homework 5: Copy data from file one, two to third
# ...
